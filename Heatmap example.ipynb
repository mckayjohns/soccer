# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from highlight_text import htext
import matplotlib as mpl

# %%
#Set general use colors
background = "#463F3A"
text_color = 'w'
primary = '#C8102E'
secondary = 'lightblue'
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

# %%
#read in the data
data = pd.read_csv('sevillah.csv')

#convert the data for the pitch size
data['x'] = data['x']*1.04
data['y'] = data['y']*.68
data['endX'] = data['endX']*1.04
data['endY'] = data['endY']*.68

#player id's from whoscored data
messi = 11119
riqui = 372827
fati = 382234
griezmann = 80241
coutinho = 80767
pedri = 402197
araujo = 384711
dest = 379205
barca = 65

#create a new data frame just for a certain player. If you want the whole team use the barca variable
r_data = data[data["playerId"]==coutinho]
r_data
# Out:
#               id  eventId  minute  second  teamId        x       y  \
# 24    2219390997       14       1     2.0      65   60.320  44.064
# 68    2219393167       42       3    43.0      65    4.576  30.192
# 92    2219394159       55       5     2.0      65   75.608  50.592
# 153   2219396817       77       8    59.0      65   55.328  63.240
# 155   2219396849       79       9     4.0      65   66.664  54.060
# 159   2219396915       81       9    10.0      65   92.040  38.556
# 216   2219398813       93      12     3.0      65   54.288  45.696
# 232   2219399505      102      13     0.0      65   65.416  54.060
# 234   2219399537      104      13     2.0      65   62.608  62.016
# 237   2219399635      107      13    12.0      65   72.176  48.484
# 301   2219402273      137      17    34.0      65   93.912   7.072
# 320   2219403203      147      19    11.0      65   64.376  59.160
# 322   2219403235      150      19    18.0      65   72.696  64.260
# 402   2219405309      188      22    54.0      65   39.416  44.064
# 404   2219405343      190      23     4.0      65   63.440  59.296
# 409   2219405443      191      23    14.0      65   34.320  65.008
# 472   2219406781      224      25    29.0      65   60.112  46.308
# 473   2219406783      225      25    31.0      65   65.000  45.016
# 474   2219406801      226      25    31.0      65   65.000  45.016
# 476   2219406873      228      25    37.0      65   77.480  42.840
# 498   2219407379      247      26    40.0      65   48.360  38.080
# 508   2219407625      255      27    15.0      65   70.200  57.936
# 511   2219407679      258      27    20.0      65   62.712  64.464
# 516   2219407837      263      27    33.0      65   68.640  66.028
# 521   2219407973      268      27    45.0      65   61.776  48.688
# 607   2219410231      315      32     2.0      65   41.704  62.764
# 670   2219411965      343      35     2.0      65   69.264  62.968
# 672   2219411991      345      35     6.0      65   68.952  64.668
# 674   2219412051      347      35    10.0      65   66.768  50.388
# 699   2219412609      371      36    24.0      65   73.216  49.572
# 721   2219413287      391      37    50.0      65   79.768  18.496
# 731   2219413655      400      38    29.0      65   72.176  50.932
# 753   2219414343      404      39    41.0      65   76.648  42.432
# 793   2219415115      421      41     8.0      65   59.072  52.768
# 845   2219416381      445      43    54.0      65   65.520  26.588
# 849   2219416439      449      44     3.0      65   73.736  38.556
# 862   2219416655      456      44    20.0      65   48.256  55.692
# 905   2219425185      471      47     1.0      65   14.560  32.572
# 911   2219425253      474      47    11.0      65   41.808  39.712
# 1000  2219427881      525      52     4.0      65   72.384  26.180
# 1043  2219429433      551      54    55.0      65   28.704  55.216
# 1058  2219429759      557      55    29.0      65   56.680  38.148
# 1062  2219429829      561      55    35.0      65   68.952  32.504
# 1071  2219429995      566      55    47.0      65   65.416  45.288
# 1090  2219430461      581      56    32.0      65   61.672  50.524
# 1107  2219430889      598      57    15.0      65   77.792  48.892
# 1128  2219431331      612      58     5.0      65  103.480  67.660
# 1150  2219431797      629      59     2.0      65   45.240  32.708
# 1227  2219434139      676      63    31.0      65   24.440  64.804
# 1305  2219436877      724      69    20.0      65  103.480  67.660
# 1320  2219437083      733      70     6.0      65   38.480  65.280
# 1322  2219437117      735      70    10.0      65   31.616  68.000
# 1359  2219439029      753      74    35.0      65    0.000   0.000
#
#       expandedMinute  period/value period/displayName  ...  \
# 24                 1             1          FirstHalf  ...
# 68                 3             1          FirstHalf  ...
# 92                 5             1          FirstHalf  ...
# 153                8             1          FirstHalf  ...
# 155                9             1          FirstHalf  ...
# 159                9             1          FirstHalf  ...
# 216               12             1          FirstHalf  ...
# 232               13             1          FirstHalf  ...
# 234               13             1          FirstHalf  ...
# 237               13             1          FirstHalf  ...
# 301               17             1          FirstHalf  ...
# 320               19             1          FirstHalf  ...
# 322               19             1          FirstHalf  ...
# 402               22             1          FirstHalf  ...
# 404               23             1          FirstHalf  ...
# 409               23             1          FirstHalf  ...
# 472               25             1          FirstHalf  ...
# 473               25             1          FirstHalf  ...
# 474               25             1          FirstHalf  ...
# 476               25             1          FirstHalf  ...
# 498               26             1          FirstHalf  ...
# 508               27             1          FirstHalf  ...
# 511               27             1          FirstHalf  ...
# 516               27             1          FirstHalf  ...
# 521               27             1          FirstHalf  ...
# 607               32             1          FirstHalf  ...
# 670               35             1          FirstHalf  ...
# 672               35             1          FirstHalf  ...
# 674               35             1          FirstHalf  ...
# 699               36             1          FirstHalf  ...
# 721               37             1          FirstHalf  ...
# 731               38             1          FirstHalf  ...
# 753               39             1          FirstHalf  ...
# 793               41             1          FirstHalf  ...
# 845               43             1          FirstHalf  ...
# 849               44             1          FirstHalf  ...
# 862               44             1          FirstHalf  ...
# 905               48             2         SecondHalf  ...
# 911               48             2         SecondHalf  ...
# 1000              53             2         SecondHalf  ...
# 1043              55             2         SecondHalf  ...
# 1058              56             2         SecondHalf  ...
# 1062              56             2         SecondHalf  ...
# 1071              56             2         SecondHalf  ...
# 1090              57             2         SecondHalf  ...
# 1107              58             2         SecondHalf  ...
# 1128              59             2         SecondHalf  ...
# 1150              60             2         SecondHalf  ...
# 1227              64             2         SecondHalf  ...
# 1305              70             2         SecondHalf  ...
# 1320              71             2         SecondHalf  ...
# 1322              71             2         SecondHalf  ...
# 1359              75             2         SecondHalf  ...
#
#       qualifiers/12/value qualifiers/13/type/value  \
# 24                    NaN                      NaN
# 68                    NaN                      NaN
# 92                    NaN                      NaN
# 153                   NaN                      NaN
# 155                   NaN                      NaN
# 159                   NaN                      NaN
# 216                   NaN                      NaN
# 232                   NaN                      NaN
# 234                   NaN                      NaN
# 237                   NaN                      NaN
# 301                   NaN                      NaN
# 320                   NaN                      NaN
# 322                   NaN                      NaN
# 402                   NaN                      NaN
# 404                   NaN                      NaN
# 409                   NaN                      NaN
# 472                   NaN                      NaN
# 473                   NaN                      NaN
# 474                   NaN                      NaN
# 476                   NaN                      NaN
# 498                   NaN                      NaN
# 508                   NaN                      NaN
# 511                   NaN                      NaN
# 516                   NaN                      NaN
# 521                   NaN                      NaN
# 607                   NaN                      NaN
# 670                   NaN                      NaN
# 672                   NaN                      NaN
# 674                   NaN                      NaN
# 699                   NaN                      NaN
# 721                   NaN                      NaN
# 731                   NaN                      NaN
# 753                   NaN                      NaN
# 793                   NaN                      NaN
# 845                   NaN                      NaN
# 849                   NaN                      NaN
# 862                   NaN                      NaN
# 905                   NaN                      NaN
# 911                   NaN                      NaN
# 1000                  NaN                      NaN
# 1043                  NaN                      NaN
# 1058                  NaN                      NaN
# 1062                  NaN                      NaN
# 1071                  NaN                      NaN
# 1090                  NaN                      NaN
# 1107                  NaN                      NaN
# 1128                  NaN                      NaN
# 1150                  NaN                      NaN
# 1227                  NaN                      NaN
# 1305                  NaN                      NaN
# 1320                  NaN                      NaN
# 1322                  NaN                      NaN
# 1359                  NaN                      NaN
#
#       qualifiers/13/type/displayName isGoal  qualifiers/11/value  \
# 24                               NaN    NaN                  NaN
# 68                               NaN    NaN                  NaN
# 92                               NaN    NaN                  NaN
# 153                              NaN    NaN                  NaN
# 155                              NaN    NaN                  NaN
# 159                              NaN   True                  NaN
# 216                              NaN    NaN                  NaN
# 232                              NaN    NaN                  NaN
# 234                              NaN    NaN                  NaN
# 237                              NaN    NaN                  NaN
# 301                              NaN    NaN                  NaN
# 320                              NaN    NaN                  NaN
# 322                              NaN    NaN                  NaN
# 402                              NaN    NaN                  NaN
# 404                              NaN    NaN                  NaN
# 409                              NaN    NaN                  NaN
# 472                              NaN    NaN                  NaN
# 473                              NaN    NaN                  NaN
# 474                              NaN    NaN                  NaN
# 476                              NaN    NaN                  NaN
# 498                              NaN    NaN                  NaN
# 508                              NaN    NaN                  NaN
# 511                              NaN    NaN                  NaN
# 516                              NaN    NaN                  NaN
# 521                              NaN    NaN                  NaN
# 607                              NaN    NaN                  NaN
# 670                              NaN    NaN                  NaN
# 672                              NaN    NaN                  NaN
# 674                              NaN    NaN                  NaN
# 699                              NaN    NaN                  NaN
# 721                              NaN    NaN                  NaN
# 731                              NaN    NaN                  NaN
# 753                              NaN    NaN                  NaN
# 793                              NaN    NaN                  NaN
# 845                              NaN    NaN                  NaN
# 849                              NaN    NaN                  NaN
# 862                              NaN    NaN                  NaN
# 905                              NaN    NaN                  NaN
# 911                              NaN    NaN                  NaN
# 1000                             NaN    NaN                  NaN
# 1043                             NaN    NaN                  NaN
# 1058                             NaN    NaN                  NaN
# 1062                             NaN    NaN                  NaN
# 1071                             NaN    NaN                  NaN
# 1090                             NaN    NaN                  NaN
# 1107                             NaN    NaN                  NaN
# 1128                             NaN    NaN                  NaN
# 1150                             NaN    NaN                  NaN
# 1227                             NaN    NaN                  NaN
# 1305                             NaN    NaN                  NaN
# 1320                             NaN    NaN                  NaN
# 1322                             NaN    NaN                  NaN
# 1359                             NaN    NaN                  NaN
#
#       satisfiedEventsTypes/13  satisfiedEventsTypes/14  \
# 24                        NaN                      NaN
# 68                        NaN                      NaN
# 92                        NaN                      NaN
# 153                       NaN                      NaN
# 155                       NaN                      NaN
# 159                       NaN                      NaN
# 216                       NaN                      NaN
# 232                       NaN                      NaN
# 234                       NaN                      NaN
# 237                       NaN                      NaN
# 301                       NaN                      NaN
# 320                       NaN                      NaN
# 322                       NaN                      NaN
# 402                       NaN                      NaN
# 404                       NaN                      NaN
# 409                       NaN                      NaN
# 472                       NaN                      NaN
# 473                       NaN                      NaN
# 474                       NaN                      NaN
# 476                       NaN                      NaN
# 498                       NaN                      NaN
# 508                       NaN                      NaN
# 511                       NaN                      NaN
# 516                       NaN                      NaN
# 521                       NaN                      NaN
# 607                       NaN                      NaN
# 670                       NaN                      NaN
# 672                       NaN                      NaN
# 674                       NaN                      NaN
# 699                       NaN                      NaN
# 721                       NaN                      NaN
# 731                       NaN                      NaN
# 753                       NaN                      NaN
# 793                       NaN                      NaN
# 845                       NaN                      NaN
# 849                       NaN                      NaN
# 862                       NaN                      NaN
# 905                       NaN                      NaN
# 911                       NaN                      NaN
# 1000                      NaN                      NaN
# 1043                      NaN                      NaN
# 1058                      NaN                      NaN
# 1062                      NaN                      NaN
# 1071                      NaN                      NaN
# 1090                      NaN                      NaN
# 1107                      NaN                      NaN
# 1128                      NaN                      NaN
# 1150                      NaN                      NaN
# 1227                      NaN                      NaN
# 1305                      NaN                      NaN
# 1320                      NaN                      NaN
# 1322                      NaN                      NaN
# 1359                      NaN                      NaN
#
#      satisfiedEventsTypes/15 cardType/value  cardType/displayName
# 24                       NaN            NaN                   NaN
# 68                       NaN            NaN                   NaN
# 92                       NaN            NaN                   NaN
# 153                      NaN            NaN                   NaN
# 155                      NaN            NaN                   NaN
# 159                      NaN            NaN                   NaN
# 216                      NaN            NaN                   NaN
# 232                      NaN            NaN                   NaN
# 234                      NaN            NaN                   NaN
# 237                      NaN            NaN                   NaN
# 301                      NaN            NaN                   NaN
# 320                      NaN            NaN                   NaN
# 322                      NaN            NaN                   NaN
# 402                      NaN            NaN                   NaN
# 404                      NaN            NaN                   NaN
# 409                      NaN            NaN                   NaN
# 472                      NaN            NaN                   NaN
# 473                      NaN            NaN                   NaN
# 474                      NaN            NaN                   NaN
# 476                      NaN            NaN                   NaN
# 498                      NaN            NaN                   NaN
# 508                      NaN            NaN                   NaN
# 511                      NaN            NaN                   NaN
# 516                      NaN            NaN                   NaN
# 521                      NaN            NaN                   NaN
# 607                      NaN            NaN                   NaN
# 670                      NaN            NaN                   NaN
# 672                      NaN            NaN                   NaN
# 674                      NaN            NaN                   NaN
# 699                      NaN            NaN                   NaN
# 721                      NaN            NaN                   NaN
# 731                      NaN            NaN                   NaN
# 753                      NaN            NaN                   NaN
# 793                      NaN            NaN                   NaN
# 845                      NaN            NaN                   NaN
# 849                      NaN            NaN                   NaN
# 862                      NaN            NaN                   NaN
# 905                      NaN            NaN                   NaN
# 911                      NaN            NaN                   NaN
# 1000                     NaN            NaN                   NaN
# 1043                     NaN            NaN                   NaN
# 1058                     NaN            NaN                   NaN
# 1062                     NaN            NaN                   NaN
# 1071                     NaN            NaN                   NaN
# 1090                     NaN            NaN                   NaN
# 1107                     NaN            NaN                   NaN
# 1128                     NaN            NaN                   NaN
# 1150                     NaN            NaN                   NaN
# 1227                     NaN            NaN                   NaN
# 1305                     NaN            NaN                   NaN
# 1320                     NaN            NaN                   NaN
# 1322                     NaN            NaN                   NaN
# 1359                     NaN            NaN                   NaN
#
# [53 rows x 85 columns]

# %%
def draw_field():# setting plot and pitch parameters, as well as style settings
    plt.axis('Off')

    # Plotting pitches using Peter McKeever's pitch dimensions 
    ly1 = [0,0,68,68,0]
    lx1 = [0,104,104,0,0]
    plt.plot(lx1,ly1,color="xkcd:off white",zorder=5, linewidth=2)

    ly2 = [13.84,13.84,54.16,54.16] 
    lx2 = [104,87.5,87.5,104]
    plt.plot(lx2,ly2,color="xkcd:off white",zorder=5, linewidth=2)

    ly3 = [13.84,13.84,54.16,54.16] 
    lx3 = [0,16.5,16.5,0]
    plt.plot(lx3,ly3,color="xkcd:off white",zorder=5, linewidth=2)  

    ly4 = [30.34,30.34,37.66,37.66]
    lx4 = [104,104.2,104.2,104]
    plt.plot(lx4,ly4,color="xkcd:off white",zorder=5, linewidth=2)

    ly5 = [30.34,30.34,37.66,37.66]
    lx5 = [0,-0.2,-0.2,0]
    plt.plot(lx5,ly5,color="xkcd:off white",zorder=5, linewidth=2)

    ly6 = [24.84,24.84,43.16,43.16]
    lx6 = [104,99.5,99.5,104]
    plt.plot(lx6,ly6,color="xkcd:off white",zorder=5, linewidth=2)

    ly7 = [24.84,24.84,43.16,43.16]
    lx7 = [0,4.5,4.5,0]
    plt.plot(lx7,ly7,color="xkcd:off white",zorder=5, linewidth=2)

    circle1 = plt.Circle((93.5,34), 9.15,ls='solid',lw=2,color="xkcd:off white", fill=False, zorder=1,alpha=1)
    circle2 = plt.Circle((10.5,34), 9.15,ls='solid',lw=2,color="xkcd:off white", fill=False, zorder=1,alpha=1)
    circle3 = plt.Circle((52, 34), 9.15,ls='solid',lw=2,color="xkcd:off white", fill=False, zorder=2,alpha=1)

    circle1 = plt.Circle((93.5,34), 9.15,ls='solid',lw=2,color="xkcd:off white", fill=False, zorder=1,alpha=1)
    circle2 = plt.Circle((10.5,34), 9.15,ls='solid',lw=2,color="xkcd:off white", fill=False, zorder=1,alpha=1)
    circle3 = plt.Circle((52, 34), 9.15,ls='solid',lw=2,color="xkcd:off white", fill=False, zorder=2,alpha=1)

    rec1 = plt.Rectangle((87.5,20), 16,30,ls='-',color="#1b1d1e", zorder=1,alpha=1, linewidth=2)
    rec2 = plt.Rectangle((0, 20), 16.5,30,ls='-',color="#1b1d1e", zorder=1,alpha=1, linewidth=2)
    rec3 = plt.Rectangle((-1,-1), 106,70,color='#1b1d1e',zorder=1,alpha=1, linewidth=2)

    vcy5 = [0,68] 
    vcx5 = [52,52]
    plt.plot(vcx5,vcy5,color="xkcd:off white",zorder=5, linewidth=2)

    plt.scatter(93,34,color="xkcd:off white",zorder=5, s=40)
    plt.scatter(11,34,color="xkcd:off white",zorder=5, s=40)
    plt.scatter(52,34,color="xkcd:off white",zorder=5, s=40)

    ax.add_artist(rec3)
    ax.add_artist(circle1)
    ax.add_artist(circle2)
    ax.add_artist(rec1)
    ax.add_artist(rec2)
    ax.add_artist(circle3)

# %%
'''
Here you create a new dataframe and set it up for easier use
'''
names = ['x pass','y pass','endX','endY','x shot','y shot','outcome']

passes = r_data.loc[r_data['type/displayName'] == 'Pass'] # select rows based on condition
shots = r_data.loc[r_data['isShot'] == True]

xpass = passes['x'].values #df -> np.array
ypass = passes['y'].values
endX = passes['endX'].values
endY = passes['endY'].values
xshot = shots['x'].values
yshot = shots['y'].values
outcome = passes['outcomeType/displayName'].values
    
df = pd.DataFrame(data=[xpass,ypass,endX,endY,xshot,yshot,outcome],index=names)
df = df.T
#df['x shot'] = df['x shot'].fillna(0)
#df['y shot'] = df['y shot'].fillna(0)

#If you want to calculate the success rate of passes
successes = len(df[df['outcome']=='Successful'])
successrate = successes/len(df['outcome'])
successrate = "{:.0%}". format(successrate)
successrate
# Out:
# '83%'

# %%
fig, ax = plt.subplots(figsize=(13,8.5))
fig.set_facecolor(background)
ax.patch.set_facecolor(background)

#Seaborn kde plot. (Heatmap)
kde = sns.kdeplot(
            df['x pass'],
            df['y pass'],
            
            shade=True,
            cmap = 'magma',
            shade_lowest=False,
            zorder = 2
            )


#Call the draw field funciton
draw_field()

#plot the passes
for x in range(len(df['x pass'])):
    if df['outcome'][x] == 'Successful':
        plt.plot((df['x pass'][x],df['endX'][x]),(df['y pass'][x],df['endY'][x]), color='#74c69d',label='Pass Locations',lw=2,zorder=2)
        plt.scatter(df['x pass'][x],df['y pass'][x], color='#1b4332',label='Pass Locations',s=75,zorder=3,edgecolors='w')
    if df['outcome'][x] == 'Unsuccessful':
        plt.plot((df['x pass'][x],df['endX'][x]),(df['y pass'][x],df['endY'][x]), color='#ef233c',label='Pass Locations',lw=2,zorder=2)
        plt.scatter(df['x pass'][x],df['y pass'][x], color='#9a031e',label='Pass Locations',s=75,zorder=3,edgecolors='w')


#Highlight Title
s = f"Barcelona Heatmap vs Sevilla" 
htext.fig_htext(s,
                x=.27,y=.9,
                fontfamily='Andale Mono',
                highlight_weights=['bold'],
                string_weight='bold',
                fontsize=24,
                color=text_color,
                #highlight_colors=['#74c69d','#ef233c'],
               )



plt.axis('off')

plt.ylim(0, 68)
plt.xlim(0, 104)

#add credentials
fig.text(.13,.1,'@mckayjohns / Twitter',fontstyle='italic',fontsize=12,fontfamily='Andale Mono',color=text_color)
#fig.text(.13,.17,f'\n{successrate} success rate',fontstyle='italic',fontsize=16,fontfamily='Andale Mono',color=text_color)
#fig.text(.13,.14,f"Came on in 75'",fontstyle='italic',fontsize=16,fontfamily='Andale Mono',color=text_color)
# Out:
# Text(0.13, 0.1, '@mckayjohns / Twitter')
