# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('laligastats.csv')

# %%
sns.distplot(data['xG.1'],kde=True)

# %%
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
sns.kdeplot(data['npxG.1'],color='red',linewidth=4).set_title('La Liga 2019/20 npxG/90,xG/90,&Goals/90',fontsize=20)
sns.kdeplot(data['xG.1'],linewidth=4)
sns.kdeplot(data['Gls.1'],linewidth=4)
plt.xlabel('Metrics per 90',fontsize=18)
plt.tick_params(labelsize=12)
