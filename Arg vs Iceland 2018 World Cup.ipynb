# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import FCPython
from pprint import pprint
import json

# %%
#read in data from my statsbomb file
with open('Statsbomb/data/events/WorldCup/7531.json') as f:
    data = json.load(f)

# %%
#Ability to look at all the data. I use this so I can look at the data while I am doing it. 
#We use pretty print to look at the json file cleanly.
#pprint(data)
# Out:
# [{'duration': 0.0,
#   'id': '0cb04be7-4165-41da-afbc-7bbd013eb3ec',
#   'index': 1,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'second': 0,
#   'tactics': {'formation': 451,
#               'lineup': [{'jersey_number': 23,
#                           'player': {'id': 3659,
#                                      'name': 'Wilfredo Daniel Caballero'},
#                           'position': {'id': 1, 'name': 'Goalkeeper'}},
#                          {'jersey_number': 18,
#                           'player': {'id': 5513,
#                                      'name': 'Eduardo Antonio Salvio'},
#                           'position': {'id': 2, 'name': 'Right Back'}},
#                          {'jersey_number': 17,
#                           'player': {'id': 3090,
#                                      'name': 'Nicolás Hernán Otamendi'},
#                           'position': {'id': 3, 'name': 'Right Center Back'}},
#                          {'jersey_number': 16,
#                           'player': {'id': 3602,
#                                      'name': 'Faustino Marcos Alberto Rojo'},
#                           'position': {'id': 5, 'name': 'Left Center Back'}},
#                          {'jersey_number': 3,
#                           'player': {'id': 5507,
#                                      'name': 'Nicolás Alejandro Tagliafico'},
#                           'position': {'id': 6, 'name': 'Left Back'}},
#                          {'jersey_number': 13,
#                           'player': {'id': 5499,
#                                      'name': 'Maximiliano Eduardo Meza'},
#                           'position': {'id': 12, 'name': 'Right Midfield'}},
#                          {'jersey_number': 5,
#                           'player': {'id': 5510,
#                                      'name': 'Lucas Rodrigo Biglia'},
#                           'position': {'id': 13,
#                                        'name': 'Right Center Midfield'}},
#                          {'jersey_number': 14,
#                           'player': {'id': 5506,
#                                      'name': 'Javier Alejandro Mascherano'},
#                           'position': {'id': 15,
#                                        'name': 'Left Center Midfield'}},
#                          {'jersey_number': 11,
#                           'player': {'id': 2995,
#                                      'name': 'Ángel Fabián Di María Hernández'},
#                           'position': {'id': 16, 'name': 'Left Midfield'}},
#                          {'jersey_number': 10,
#                           'player': {'id': 5503,
#                                      'name': 'Lionel Andrés Messi Cuccittini'},
#                           'position': {'id': 19,
#                                        'name': 'Center Attacking Midfield'}},
#                          {'jersey_number': 19,
#                           'player': {'id': 3237,
#                                      'name': 'Sergio Leonel Agüero del '
#                                              'Castillo'},
#                           'position': {'id': 23, 'name': 'Center Forward'}}]},
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 35, 'name': 'Starting XI'}},
#  {'duration': 0.0,
#   'id': '7771f727-d7f9-4e52-89df-0f1a5ebb72c6',
#   'index': 2,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'second': 0,
#   'tactics': {'formation': 4411,
#               'lineup': [{'jersey_number': 1,
#                           'player': {'id': 5498,
#                                      'name': 'Hannes Þór Halldórsson'},
#                           'position': {'id': 1, 'name': 'Goalkeeper'}},
#                          {'jersey_number': 2,
#                           'player': {'id': 5508,
#                                      'name': 'Birkir Már Sævarsson'},
#                           'position': {'id': 2, 'name': 'Right Back'}},
#                          {'jersey_number': 14,
#                           'player': {'id': 5505, 'name': 'Kári Árnason'},
#                           'position': {'id': 3, 'name': 'Right Center Back'}},
#                          {'jersey_number': 6,
#                           'player': {'id': 5511, 'name': 'Ragnar Sigurðsson'},
#                           'position': {'id': 5, 'name': 'Left Center Back'}},
#                          {'jersey_number': 18,
#                           'player': {'id': 5501,
#                                      'name': 'Hörður Björgvin Magnússon'},
#                           'position': {'id': 6, 'name': 'Left Back'}},
#                          {'jersey_number': 17,
#                           'player': {'id': 5515,
#                                      'name': 'Aron Einar Gunnarsson'},
#                           'position': {'id': 9,
#                                        'name': 'Right Defensive Midfield'}},
#                          {'jersey_number': 20,
#                           'player': {'id': 5512, 'name': 'Emil Hallfreðsson'},
#                           'position': {'id': 11,
#                                        'name': 'Left Defensive Midfield'}},
#                          {'jersey_number': 7,
#                           'player': {'id': 3720,
#                                      'name': 'Johann Berg Guðmunds\xadson'},
#                           'position': {'id': 12, 'name': 'Right Midfield'}},
#                          {'jersey_number': 8,
#                           'player': {'id': 5509, 'name': 'Birkir Bjarnason'},
#                           'position': {'id': 16, 'name': 'Left Midfield'}},
#                          {'jersey_number': 11,
#                           'player': {'id': 5514, 'name': 'Alfreð Finnbogason'},
#                           'position': {'id': 23, 'name': 'Center Forward'}},
#                          {'jersey_number': 10,
#                           'player': {'id': 3944,
#                                      'name': 'Gylfi Þór Sigurðsson'},
#                           'position': {'id': 25,
#                                        'name': 'Secondary Striker'}}]},
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 35, 'name': 'Starting XI'}},
#  {'duration': 9.093,
#   'id': '3a40b4d3-93db-4562-b8bf-71baa012f62a',
#   'index': 3,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['a9bfb244-65b5-474c-8229-033b41b8a50e'],
#   'second': 0,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 18, 'name': 'Half Start'}},
#  {'duration': 9.333,
#   'id': 'a9bfb244-65b5-474c-8229-033b41b8a50e',
#   'index': 4,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['3a40b4d3-93db-4562-b8bf-71baa012f62a'],
#   'second': 0,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 18, 'name': 'Half Start'}},
#  {'duration': 1.133,
#   'id': '50f2b263-230c-4184-b7c1-d4e63aaf0c02',
#   'index': 5,
#   'location': [61.0, 41.0],
#   'minute': 0,
#   'pass': {'angle': -2.4592762,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [45.0, 28.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 20.615528,
#            'recipient': {'id': 5509, 'name': 'Birkir Bjarnason'},
#            'type': {'id': 65, 'name': 'Kick Off'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3720, 'name': 'Johann Berg Guðmunds\xadson'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['10c9492e-4ee5-4f96-8742-b493613ff99c'],
#   'second': 0,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:00.900',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 1.08,
#   'id': '12b914fb-1c79-4f3c-8cdb-7d7639563d67',
#   'index': 6,
#   'location': [61.0, 32.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3237, 'name': 'Sergio Leonel Agüero del Castillo'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['10c9492e-4ee5-4f96-8742-b493613ff99c',
#                      '18fe9c01-f72c-42a4-8b09-21f733b3a206',
#                      'b61ae56d-6d4c-4beb-b3e8-8a4f54fb617a'],
#   'second': 1,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:01.740',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '10c9492e-4ee5-4f96-8742-b493613ff99c',
#   'index': 7,
#   'location': [45.0, 28.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5509, 'name': 'Birkir Bjarnason'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['12b914fb-1c79-4f3c-8cdb-7d7639563d67',
#                      '50f2b263-230c-4184-b7c1-d4e63aaf0c02'],
#   'second': 2,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:02.033',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [46.0, 31.0]},
#   'duration': 0.627,
#   'id': 'b61ae56d-6d4c-4beb-b3e8-8a4f54fb617a',
#   'index': 8,
#   'location': [45.0, 28.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5509, 'name': 'Birkir Bjarnason'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['10c9492e-4ee5-4f96-8742-b493613ff99c',
#                      '12b914fb-1c79-4f3c-8cdb-7d7639563d67',
#                      '18fe9c01-f72c-42a4-8b09-21f733b3a206'],
#   'second': 2,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:02.033',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 2.533,
#   'id': '18fe9c01-f72c-42a4-8b09-21f733b3a206',
#   'index': 9,
#   'location': [46.0, 31.0],
#   'minute': 0,
#   'pass': {'angle': 0.5565993,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [91.0, 59.0],
#            'height': {'id': 3, 'name': 'High Pass'},
#            'length': 53.0,
#            'outcome': {'id': 9, 'name': 'Incomplete'},
#            'recipient': {'id': 5505, 'name': 'Kári Árnason'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5509, 'name': 'Birkir Bjarnason'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['12b914fb-1c79-4f3c-8cdb-7d7639563d67',
#                      '49ec266a-a640-44f0-9809-0e2c335b93e5',
#                      'b6627893-865a-4e77-bb01-eaf8470339e9'],
#   'second': 2,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:02.660',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '49ec266a-a640-44f0-9809-0e2c335b93e5',
#   'index': 10,
#   'location': [91.0, 60.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5505, 'name': 'Kári Árnason'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['18fe9c01-f72c-42a4-8b09-21f733b3a206'],
#   'second': 5,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:05.193',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duel': {'type': {'id': 10, 'name': 'Aerial Lost'}},
#   'id': '128bc057-4af1-4e60-8c50-6e530df0d1b1',
#   'index': 11,
#   'location': [91.0, 59.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5505, 'name': 'Kári Árnason'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['b6627893-865a-4e77-bb01-eaf8470339e9'],
#   'second': 5,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:05.193',
#   'type': {'id': 4, 'name': 'Duel'},
#   'under_pressure': True},
#  {'duration': 1.24,
#   'id': 'b6627893-865a-4e77-bb01-eaf8470339e9',
#   'index': 12,
#   'location': [30.0, 22.0],
#   'minute': 0,
#   'pass': {'aerial_won': True,
#            'angle': -0.5070985,
#            'end_location': [48.0, 12.0],
#            'height': {'id': 2, 'name': 'Low Pass'},
#            'length': 20.59126,
#            'recipient': {'id': 2995, 'name': 'Ángel Fabián Di María Hernández'},
#            'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['128bc057-4af1-4e60-8c50-6e530df0d1b1',
#                      '17994a3a-2c21-44f0-a6ae-b621bca25644',
#                      '18fe9c01-f72c-42a4-8b09-21f733b3a206'],
#   'second': 5,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:05.193',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': '17994a3a-2c21-44f0-a6ae-b621bca25644',
#   'index': 13,
#   'location': [48.0, 12.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 2995, 'name': 'Ángel Fabián Di María Hernández'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['b6627893-865a-4e77-bb01-eaf8470339e9'],
#   'second': 6,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:06.433',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [36.0, 8.0]},
#   'duration': 3.24,
#   'id': '46a41141-e3d8-4024-8c21-7d29638085be',
#   'index': 14,
#   'location': [48.0, 12.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 2995, 'name': 'Ángel Fabián Di María Hernández'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['17994a3a-2c21-44f0-a6ae-b621bca25644',
#                      '500bee34-5228-4f04-b5d0-61a639ccc653',
#                      '90f2fdd5-678b-4ba3-8a26-1f2ab3b2fd6b'],
#   'second': 6,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:06.433',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'counterpress': True,
#   'duration': 1.466,
#   'id': '90f2fdd5-678b-4ba3-8a26-1f2ab3b2fd6b',
#   'index': 15,
#   'location': [81.0, 70.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3944, 'name': 'Gylfi Þór Sigurðsson'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['46a41141-e3d8-4024-8c21-7d29638085be'],
#   'second': 7,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:07.713',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '500bee34-5228-4f04-b5d0-61a639ccc653',
#   'index': 16,
#   'location': [36.0, 8.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 2995, 'name': 'Ángel Fabián Di María Hernández'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['1ec5bf17-8629-4b85-aed1-3ba5ef41c22f'],
#   'second': 9,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:09.673',
#   'type': {'id': 3, 'name': 'Dispossessed'},
#   'under_pressure': True},
#  {'counterpress': True,
#   'duel': {'outcome': {'id': 4, 'name': 'Won'},
#            'type': {'id': 11, 'name': 'Tackle'}},
#   'id': '1ec5bf17-8629-4b85-aed1-3ba5ef41c22f',
#   'index': 17,
#   'location': [85.0, 73.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3944, 'name': 'Gylfi Þór Sigurðsson'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['500bee34-5228-4f04-b5d0-61a639ccc653'],
#   'second': 9,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:09.673',
#   'type': {'id': 4, 'name': 'Duel'},
#   'under_pressure': True},
#  {'carry': {'end_location': [92.0, 61.0]},
#   'duration': 2.307,
#   'id': 'b2bd6968-3d9c-40e3-84c2-13a37735c715',
#   'index': 18,
#   'location': [85.0, 73.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3944, 'name': 'Gylfi Þór Sigurðsson'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['1ec5bf17-8629-4b85-aed1-3ba5ef41c22f',
#                      'de7e59f9-6405-4093-9410-706bbcc78a8b'],
#   'second': 9,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:09.673',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.64,
#   'id': 'de7e59f9-6405-4093-9410-706bbcc78a8b',
#   'index': 19,
#   'location': [92.0, 61.0],
#   'minute': 0,
#   'pass': {'angle': -0.7086263,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [99.0, 55.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 9.219544,
#            'outcome': {'id': 9, 'name': 'Incomplete'},
#            'recipient': {'id': 5514, 'name': 'Alfreð Finnbogason'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3944, 'name': 'Gylfi Þór Sigurðsson'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['24302e0a-7a7a-4067-9c28-7068f0af25fc',
#                      'babc35ec-22c8-4145-a9b7-65e5a4141c42'],
#   'second': 11,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:11.980',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 0.719,
#   'id': 'f5e4966d-5647-4aab-b318-dfafc101aa0f',
#   'index': 20,
#   'location': [20.0, 29.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['24302e0a-7a7a-4067-9c28-7068f0af25fc'],
#   'second': 12,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:12.033',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '24302e0a-7a7a-4067-9c28-7068f0af25fc',
#   'index': 21,
#   'location': [100.0, 54.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5514, 'name': 'Alfreð Finnbogason'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['de7e59f9-6405-4093-9410-706bbcc78a8b',
#                      'f5e4966d-5647-4aab-b318-dfafc101aa0f'],
#   'second': 12,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:12.620',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'id': 'babc35ec-22c8-4145-a9b7-65e5a4141c42',
#   'index': 22,
#   'interception': {'outcome': {'id': 13, 'name': 'Lost In Play'}},
#   'location': [22.0, 26.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['de7e59f9-6405-4093-9410-706bbcc78a8b'],
#   'second': 12,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:12.620',
#   'type': {'id': 10, 'name': 'Interception'}},
#  {'id': 'b22999f4-56fa-41e1-b1fd-a807e156103b',
#   'index': 23,
#   'location': [95.0, 53.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3944, 'name': 'Gylfi Þór Sigurðsson'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'second': 13,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:13.180',
#   'type': {'id': 2, 'name': 'Ball Recovery'}},
#  {'duration': 1.853,
#   'id': 'be4445dc-d4bf-4f3c-9888-7d22155febe7',
#   'index': 24,
#   'location': [96.0, 53.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3944, 'name': 'Gylfi Þór Sigurðsson'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['17080e84-245f-40dc-b621-25b4dd067192'],
#   'second': 13,
#   'shot': {'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [120.0, 46.7, 0.1],
#            'first_time': True,
#            'freeze_frame': [{'location': [101.0, 52.0],
#                              'player': {'id': 3602,
#                                         'name': 'Faustino Marcos Alberto Rojo'},
#                              'position': {'id': 5, 'name': 'Left Center Back'},
#                              'teammate': False},
#                             {'location': [101.0, 53.0],
#                              'player': {'id': 5514,
#                                         'name': 'Alfreð Finnbogason'},
#                              'position': {'id': 23, 'name': 'Center Forward'},
#                              'teammate': True},
#                             {'location': [98.0, 50.0],
#                              'player': {'id': 3090,
#                                         'name': 'Nicolás Hernán Otamendi'},
#                              'position': {'id': 3, 'name': 'Right Center Back'},
#                              'teammate': False},
#                             {'location': [92.0, 36.0],
#                              'player': {'id': 5499,
#                                         'name': 'Maximiliano Eduardo Meza'},
#                              'position': {'id': 12, 'name': 'Right Midfield'},
#                              'teammate': False},
#                             {'location': [102.0, 36.0],
#                              'player': {'id': 5513,
#                                         'name': 'Eduardo Antonio Salvio'},
#                              'position': {'id': 2, 'name': 'Right Back'},
#                              'teammate': False},
#                             {'location': [103.0, 56.0],
#                              'player': {'id': 5507,
#                                         'name': 'Nicolás Alejandro Tagliafico'},
#                              'position': {'id': 6, 'name': 'Left Back'},
#                              'teammate': False},
#                             {'location': [97.0, 56.0],
#                              'player': {'id': 5506,
#                                         'name': 'Javier Alejandro Mascherano'},
#                              'position': {'id': 15,
#                                           'name': 'Left Center Midfield'},
#                              'teammate': False},
#                             {'location': [98.0, 58.0],
#                              'player': {'id': 2995,
#                                         'name': 'Ángel Fabián Di María '
#                                                 'Hernández'},
#                              'position': {'id': 16, 'name': 'Left Midfield'},
#                              'teammate': False},
#                             {'location': [92.0, 58.0],
#                              'player': {'id': 5510,
#                                         'name': 'Lucas Rodrigo Biglia'},
#                              'position': {'id': 13,
#                                           'name': 'Right Center Midfield'},
#                              'teammate': False},
#                             {'location': [102.0, 70.0],
#                              'player': {'id': 3720,
#                                         'name': 'Johann Berg Guðmunds\xadson'},
#                              'position': {'id': 12, 'name': 'Right Midfield'},
#                              'teammate': True},
#                             {'location': [120.0, 43.0],
#                              'player': {'id': 3659,
#                                         'name': 'Wilfredo Daniel Caballero'},
#                              'position': {'id': 1, 'name': 'Goalkeeper'},
#                              'teammate': False}],
#            'outcome': {'id': 98, 'name': 'Off T'},
#            'statsbomb_xg': 0.02143235,
#            'technique': {'id': 93, 'name': 'Normal'},
#            'type': {'id': 87, 'name': 'Open Play'}},
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:13.300',
#   'type': {'id': 16, 'name': 'Shot'}},
#  {'goalkeeper': {'end_location': [4.0, 39.0],
#                  'position': {'id': 44, 'name': 'Set'},
#                  'type': {'id': 32, 'name': 'Shot Faced'}},
#   'id': '17080e84-245f-40dc-b621-25b4dd067192',
#   'index': 25,
#   'location': [1.0, 38.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3659, 'name': 'Wilfredo Daniel Caballero'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 2,
#   'possession_team': {'id': 793, 'name': 'Iceland'},
#   'related_events': ['be4445dc-d4bf-4f3c-9888-7d22155febe7'],
#   'second': 15,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:15.153',
#   'type': {'id': 23, 'name': 'Goal Keeper'}},
#  {'duration': 0.88,
#   'id': '6460427e-3874-4698-9534-898be8fb0052',
#   'index': 26,
#   'location': [6.0, 38.0],
#   'minute': 0,
#   'pass': {'angle': -1.5253731,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [7.0, 16.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 22.022715,
#            'recipient': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#            'type': {'id': 63, 'name': 'Goal Kick'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3659, 'name': 'Wilfredo Daniel Caballero'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['d31ff518-e4cf-4ab5-8fc3-9a89b77197e8'],
#   'second': 27,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:27.633',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'd31ff518-e4cf-4ab5-8fc3-9a89b77197e8',
#   'index': 27,
#   'location': [7.0, 16.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['6460427e-3874-4698-9534-898be8fb0052'],
#   'second': 28,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:28.513',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [13.0, 14.0]},
#   'duration': 2.88,
#   'id': '21435bf5-9479-4cac-b384-d110e3129ce1',
#   'index': 28,
#   'location': [7.0, 16.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['3d0c3bcf-559d-4f69-afe1-667e79faebdb',
#                      'd31ff518-e4cf-4ab5-8fc3-9a89b77197e8'],
#   'second': 28,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:28.513',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.48,
#   'id': '3d0c3bcf-559d-4f69-afe1-667e79faebdb',
#   'index': 29,
#   'location': [13.0, 14.0],
#   'minute': 0,
#   'pass': {'angle': 2.010639,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [5.0, 31.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 18.788294,
#            'recipient': {'id': 3659, 'name': 'Wilfredo Daniel Caballero'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['c563bd1b-9997-4e4c-816b-ec77b1dbdb5e'],
#   'second': 31,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:31.393',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'c563bd1b-9997-4e4c-816b-ec77b1dbdb5e',
#   'index': 30,
#   'location': [5.0, 31.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3659, 'name': 'Wilfredo Daniel Caballero'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['3d0c3bcf-559d-4f69-afe1-667e79faebdb'],
#   'second': 32,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:32.873',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [10.0, 25.0]},
#   'duration': 2.32,
#   'id': '00f42fdc-824d-42e7-8c80-16dbb0871130',
#   'index': 31,
#   'location': [5.0, 31.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3659, 'name': 'Wilfredo Daniel Caballero'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['8b73cb56-6f52-4daa-aa44-18f817791f6d',
#                      'c563bd1b-9997-4e4c-816b-ec77b1dbdb5e'],
#   'second': 32,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:32.873',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.88,
#   'id': '8b73cb56-6f52-4daa-aa44-18f817791f6d',
#   'index': 32,
#   'location': [10.0, 25.0],
#   'minute': 0,
#   'pass': {'angle': -0.9357696,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [24.0, 6.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 23.600847,
#            'recipient': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3659, 'name': 'Wilfredo Daniel Caballero'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['d3fa5806-8119-49d9-a79b-7aad190e0041'],
#   'second': 35,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:35.193',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'd3fa5806-8119-49d9-a79b-7aad190e0041',
#   'index': 33,
#   'location': [24.0, 6.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['8b73cb56-6f52-4daa-aa44-18f817791f6d'],
#   'second': 37,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:37.073',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [23.0, 6.0]},
#   'duration': 1.32,
#   'id': 'b93a9286-2e79-4a7c-aba0-dbcdcbd71c62',
#   'index': 34,
#   'location': [24.0, 6.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['45e56194-3de9-434b-b0a2-a1a3799789d8',
#                      'd3fa5806-8119-49d9-a79b-7aad190e0041',
#                      'f6e52144-dd96-4e98-b0db-147356b33904'],
#   'second': 37,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:37.073',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 0.68,
#   'id': '45e56194-3de9-434b-b0a2-a1a3799789d8',
#   'index': 35,
#   'location': [94.0, 73.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3944, 'name': 'Gylfi Þór Sigurðsson'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['b93a9286-2e79-4a7c-aba0-dbcdcbd71c62',
#                      'f6e52144-dd96-4e98-b0db-147356b33904'],
#   'second': 38,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:38.153',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 1.2,
#   'id': 'f6e52144-dd96-4e98-b0db-147356b33904',
#   'index': 36,
#   'location': [23.0, 6.0],
#   'minute': 0,
#   'pass': {'angle': -0.09966865,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [43.0, 4.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 20.09975,
#            'recipient': {'id': 5507, 'name': 'Nicolás Alejandro Tagliafico'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['3f231963-3228-41ac-be70-08e2e5120e9f',
#                      '45e56194-3de9-434b-b0a2-a1a3799789d8'],
#   'second': 38,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:38.393',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': '3f231963-3228-41ac-be70-08e2e5120e9f',
#   'index': 37,
#   'location': [43.0, 4.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5507, 'name': 'Nicolás Alejandro Tagliafico'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['f6e52144-dd96-4e98-b0db-147356b33904'],
#   'second': 39,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:39.593',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [43.0, 3.0]},
#   'duration': 1.56,
#   'id': '4473eb4c-467a-45b5-8dba-c289037a81ea',
#   'index': 38,
#   'location': [43.0, 4.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5507, 'name': 'Nicolás Alejandro Tagliafico'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['1a8bb2cb-da80-4a2a-9b78-7b74c13dc979',
#                      '3f231963-3228-41ac-be70-08e2e5120e9f',
#                      'ef0ab61a-c00c-4e1d-8a90-2e317102e379'],
#   'second': 39,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:39.593',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 0.706,
#   'id': 'ef0ab61a-c00c-4e1d-8a90-2e317102e379',
#   'index': 39,
#   'location': [77.0, 77.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3720, 'name': 'Johann Berg Guðmunds\xadson'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['4473eb4c-467a-45b5-8dba-c289037a81ea'],
#   'second': 39,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:00:39.833',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 1.56,
#   'id': '1a8bb2cb-da80-4a2a-9b78-7b74c13dc979',
#   'index': 40,
#   'location': [43.0, 3.0],
#   'minute': 0,
#   'pass': {'angle': 3.1415927,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [17.0, 3.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 26.0,
#            'recipient': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5507, 'name': 'Nicolás Alejandro Tagliafico'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['d0547cbb-735b-44e4-a0bd-2ee57a9dfd40'],
#   'second': 41,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:41.153',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'd0547cbb-735b-44e4-a0bd-2ee57a9dfd40',
#   'index': 41,
#   'location': [17.0, 3.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['1a8bb2cb-da80-4a2a-9b78-7b74c13dc979'],
#   'second': 42,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:42.713',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [23.0, 26.0]},
#   'duration': 4.32,
#   'id': '6ac23248-2941-4978-9e77-2b98970aa27e',
#   'index': 42,
#   'location': [17.0, 3.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['6a332767-53fc-483e-b373-b3a9b54767b3',
#                      'd0547cbb-735b-44e4-a0bd-2ee57a9dfd40'],
#   'second': 42,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:42.713',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 2.08,
#   'id': '6a332767-53fc-483e-b373-b3a9b54767b3',
#   'index': 43,
#   'location': [23.0, 26.0],
#   'minute': 0,
#   'pass': {'angle': 1.5337762,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [24.0, 53.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 27.018513,
#            'recipient': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3602, 'name': 'Faustino Marcos Alberto Rojo'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['99827258-14db-42b1-814c-0b23af330e7c'],
#   'second': 47,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:47.033',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '99827258-14db-42b1-814c-0b23af330e7c',
#   'index': 44,
#   'location': [24.0, 53.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['6a332767-53fc-483e-b373-b3a9b54767b3'],
#   'second': 49,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:49.113',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [29.0, 59.0]},
#   'duration': 1.6,
#   'id': '62827d91-05b2-4390-b048-c788fa8a9faf',
#   'index': 45,
#   'location': [24.0, 53.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['99827258-14db-42b1-814c-0b23af330e7c',
#                      'a2a6af74-9eeb-4d99-be91-734f2e989812'],
#   'second': 49,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:49.113',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.12,
#   'id': 'a2a6af74-9eeb-4d99-be91-734f2e989812',
#   'index': 46,
#   'location': [29.0, 59.0],
#   'minute': 0,
#   'pass': {'angle': 0.9272952,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [41.0, 75.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 20.0,
#            'recipient': {'id': 5513, 'name': 'Eduardo Antonio Salvio'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['3ef17ccc-54f5-4cb5-b5ff-1c90b1456822'],
#   'second': 50,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:50.713',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '3ef17ccc-54f5-4cb5-b5ff-1c90b1456822',
#   'index': 47,
#   'location': [41.0, 75.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5513, 'name': 'Eduardo Antonio Salvio'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['a2a6af74-9eeb-4d99-be91-734f2e989812'],
#   'second': 51,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:51.833',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [45.0, 75.0]},
#   'duration': 1.12,
#   'id': '08a78cda-6d6e-4e2a-8389-e492241c358c',
#   'index': 48,
#   'location': [41.0, 75.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5513, 'name': 'Eduardo Antonio Salvio'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['3ef17ccc-54f5-4cb5-b5ff-1c90b1456822',
#                      '40626709-a6fb-4ff6-a52c-8eca7313a37e'],
#   'second': 51,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:51.833',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.0,
#   'id': '40626709-a6fb-4ff6-a52c-8eca7313a37e',
#   'index': 49,
#   'location': [45.0, 75.0],
#   'minute': 0,
#   'pass': {'angle': -1.4601392,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [47.0, 57.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 18.110771,
#            'recipient': {'id': 5506, 'name': 'Javier Alejandro Mascherano'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5513, 'name': 'Eduardo Antonio Salvio'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['730045ea-1d06-4cf9-918b-73fdfa3f193c'],
#   'second': 52,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:52.953',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '730045ea-1d06-4cf9-918b-73fdfa3f193c',
#   'index': 50,
#   'location': [47.0, 57.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5506, 'name': 'Javier Alejandro Mascherano'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['40626709-a6fb-4ff6-a52c-8eca7313a37e'],
#   'second': 53,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:53.953',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.56,
#   'id': 'e4b06732-accb-4562-8255-4d8c3fc020ff',
#   'index': 51,
#   'location': [44.0, 53.0],
#   'minute': 0,
#   'pass': {'angle': 2.5161076,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [26.0, 66.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 22.203604,
#            'recipient': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5506, 'name': 'Javier Alejandro Mascherano'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['2ace3639-d5f5-4a60-bb6e-de7dd50b582c'],
#   'second': 53,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:53.953',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '2ace3639-d5f5-4a60-bb6e-de7dd50b582c',
#   'index': 52,
#   'location': [26.0, 66.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['e4b06732-accb-4562-8255-4d8c3fc020ff'],
#   'second': 55,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:55.513',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [29.0, 66.0]},
#   'duration': 1.88,
#   'id': '589e9a10-9fcf-4611-8b5e-eaf22254d88f',
#   'index': 53,
#   'location': [26.0, 66.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['2ace3639-d5f5-4a60-bb6e-de7dd50b582c',
#                      '6d757eea-7242-47ad-8ff0-0f441ab16e3e'],
#   'second': 55,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:55.513',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.92,
#   'id': '6d757eea-7242-47ad-8ff0-0f441ab16e3e',
#   'index': 54,
#   'location': [29.0, 66.0],
#   'minute': 0,
#   'pass': {'angle': -1.3554386,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [36.0, 34.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 32.75668,
#            'recipient': {'id': 5510, 'name': 'Lucas Rodrigo Biglia'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 3090, 'name': 'Nicolás Hernán Otamendi'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['94f6c8d8-e34d-4168-a87d-23f6ed754091'],
#   'second': 57,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:57.393',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '94f6c8d8-e34d-4168-a87d-23f6ed754091',
#   'index': 55,
#   'location': [36.0, 34.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5510, 'name': 'Lucas Rodrigo Biglia'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 3,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['6d757eea-7242-47ad-8ff0-0f441ab16e3e'],
#   'second': 59,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:00:59.313',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.36,
#   'id': '070926eb-7041-4626-bbc1-e62658b0036d',
#   'index': 56,
#   'location': [42.0, 25.0],
#   'minute': 0,
#   'pass': {'angle': -1.00748,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [54.0, 6.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 22.472204,
#            'recipient': {'id': 5507, 'name': 'Nicolás Alejandro Tagliafico'}},
#   'period': 1,
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'player': {'id': 5510, 'name': 'Lucas Rodrigo Biglia'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 3,
# ...
#   'index': 1530,
#   'location': [79.0, 23.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5506, 'name': 'Javier Alejandro Mascherano'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['3a459c8a-c954-4582-b55a-46e4965f8327',
#                      '6a3ee20a-3700-47cc-ad45-f5ff80d38699'],
#   'second': 31,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:31.753',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.92,
#   'id': '6a3ee20a-3700-47cc-ad45-f5ff80d38699',
#   'index': 1531,
#   'location': [74.0, 26.0],
#   'minute': 39,
#   'pass': {'angle': 1.080839,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [82.0, 41.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 17.0,
#            'recipient': {'id': 5503, 'name': 'Lionel Andrés Messi Cuccittini'}},
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5506, 'name': 'Javier Alejandro Mascherano'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['83d636f4-eb20-4bc3-8490-cf7596231266'],
#   'second': 33,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:33.513',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '83d636f4-eb20-4bc3-8490-cf7596231266',
#   'index': 1532,
#   'location': [82.0, 41.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5503, 'name': 'Lionel Andrés Messi Cuccittini'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['6a3ee20a-3700-47cc-ad45-f5ff80d38699'],
#   'second': 34,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:34.433',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [85.0, 41.0]},
#   'duration': 2.68,
#   'id': 'eb9df0ac-29e9-45c8-b748-3001efe0635b',
#   'index': 1533,
#   'location': [82.0, 41.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5503, 'name': 'Lionel Andrés Messi Cuccittini'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['4fce5df1-1b51-48c7-91b2-c75865f2f0c6',
#                      '83d636f4-eb20-4bc3-8490-cf7596231266',
#                      'ac4ea742-e93c-4980-95c7-1a363118fec6'],
#   'second': 34,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:34.433',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.32,
#   'id': '4fce5df1-1b51-48c7-91b2-c75865f2f0c6',
#   'index': 1534,
#   'location': [39.0, 39.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5514, 'name': 'Alfreð Finnbogason'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['ac4ea742-e93c-4980-95c7-1a363118fec6',
#                      'eb9df0ac-29e9-45c8-b748-3001efe0635b'],
#   'second': 35,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:39:35.833',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 1.24,
#   'id': 'ac4ea742-e93c-4980-95c7-1a363118fec6',
#   'index': 1535,
#   'location': [85.0, 41.0],
#   'minute': 39,
#   'pass': {'angle': 1.1071488,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'end_location': [94.0, 59.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 20.12461,
#            'recipient': {'id': 5513, 'name': 'Eduardo Antonio Salvio'}},
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5503, 'name': 'Lionel Andrés Messi Cuccittini'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['1a6836b3-9beb-4ea5-93bd-615960a6ca2d',
#                      '4fce5df1-1b51-48c7-91b2-c75865f2f0c6'],
#   'second': 37,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:37.113',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': '1a6836b3-9beb-4ea5-93bd-615960a6ca2d',
#   'index': 1536,
#   'location': [94.0, 59.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5513, 'name': 'Eduardo Antonio Salvio'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['ac4ea742-e93c-4980-95c7-1a363118fec6'],
#   'second': 38,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:38.353',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [101.0, 65.0]},
#   'duration': 1.72,
#   'id': '969beadd-ffde-490d-89d0-5cc012bc1ace',
#   'index': 1537,
#   'location': [94.0, 59.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5513, 'name': 'Eduardo Antonio Salvio'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['1a6836b3-9beb-4ea5-93bd-615960a6ca2d',
#                      'd3b3187b-07ac-4f35-92d1-a21d76240fed'],
#   'second': 38,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:38.353',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.64,
#   'id': 'd3b3187b-07ac-4f35-92d1-a21d76240fed',
#   'index': 1538,
#   'location': [101.0, 65.0],
#   'minute': 39,
#   'pass': {'angle': 0.11710875,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [118.0, 67.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 17.117243,
#            'recipient': {'id': 5499, 'name': 'Maximiliano Eduardo Meza'}},
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5513, 'name': 'Eduardo Antonio Salvio'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['215ea019-7fbd-4949-89ba-f3ea0b0b4626'],
#   'second': 40,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:40.073',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 0.693,
#   'id': '1843dddb-7be6-44d7-ac4a-1eb5a379b764',
#   'index': 1539,
#   'location': [7.0, 20.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5501, 'name': 'Hörður Björgvin Magnússon'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['215ea019-7fbd-4949-89ba-f3ea0b0b4626',
#                      '9b3aab8d-2021-4743-bcba-c0eec08bf0d8',
#                      'fe43848d-1458-4bc2-97cb-8c950ceddcfb'],
#   'second': 41,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:39:41.420',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '215ea019-7fbd-4949-89ba-f3ea0b0b4626',
#   'index': 1540,
#   'location': [118.0, 67.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5499, 'name': 'Maximiliano Eduardo Meza'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['1843dddb-7be6-44d7-ac4a-1eb5a379b764',
#                      'd3b3187b-07ac-4f35-92d1-a21d76240fed'],
#   'second': 41,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:41.713',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [118.0, 67.0]},
#   'duration': 0.16,
#   'id': 'fe43848d-1458-4bc2-97cb-8c950ceddcfb',
#   'index': 1541,
#   'location': [118.0, 67.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5499, 'name': 'Maximiliano Eduardo Meza'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['1843dddb-7be6-44d7-ac4a-1eb5a379b764',
#                      '215ea019-7fbd-4949-89ba-f3ea0b0b4626',
#                      '9b3aab8d-2021-4743-bcba-c0eec08bf0d8'],
#   'second': 41,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:41.713',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.0,
#   'id': '9b3aab8d-2021-4743-bcba-c0eec08bf0d8',
#   'index': 1542,
#   'location': [118.0, 67.0],
#   'minute': 39,
#   'pass': {'angle': -1.815775,
#            'body_part': {'id': 40, 'name': 'Right Foot'},
#            'end_location': [117.0, 63.0],
#            'height': {'id': 1, 'name': 'Ground Pass'},
#            'length': 4.1231055,
#            'recipient': {'id': 5510, 'name': 'Lucas Rodrigo Biglia'}},
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5499, 'name': 'Maximiliano Eduardo Meza'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['1843dddb-7be6-44d7-ac4a-1eb5a379b764',
#                      'e240e992-91ee-479e-9b11-bb850ddb7d7d'],
#   'second': 41,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:41.873',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': 'e240e992-91ee-479e-9b11-bb850ddb7d7d',
#   'index': 1543,
#   'location': [117.0, 63.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5510, 'name': 'Lucas Rodrigo Biglia'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['9b3aab8d-2021-4743-bcba-c0eec08bf0d8'],
#   'second': 42,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:42.873',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [117.0, 47.0]},
#   'duration': 0.52,
#   'id': 'ddccb856-2672-46af-873b-4cfc886605de',
#   'index': 1544,
#   'location': [117.0, 63.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5510, 'name': 'Lucas Rodrigo Biglia'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['8a188c8e-dfc5-4daf-af9a-fcb5e5f5bbb6',
#                      'b3bc2a0c-d1da-40b0-8c78-3d80330e8356',
#                      'e240e992-91ee-479e-9b11-bb850ddb7d7d'],
#   'second': 42,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:42.873',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'id': 'b3bc2a0c-d1da-40b0-8c78-3d80330e8356',
#   'index': 1545,
#   'interception': {'outcome': {'id': 14, 'name': 'Lost Out'}},
#   'location': [5.0, 32.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5511, 'name': 'Ragnar Sigurðsson'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['ddccb856-2672-46af-873b-4cfc886605de'],
#   'second': 43,
#   'team': {'id': 793, 'name': 'Iceland'},
#   'timestamp': '00:39:43.060',
#   'type': {'id': 10, 'name': 'Interception'}},
#  {'id': '8a188c8e-dfc5-4daf-af9a-fcb5e5f5bbb6',
#   'index': 1546,
#   'location': [117.0, 47.0],
#   'minute': 39,
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5510, 'name': 'Lucas Rodrigo Biglia'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 55,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'second': 43,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:39:43.393',
#   'type': {'id': 38, 'name': 'Miscontrol'}},
#  {'duration': 1.827,
#   'id': 'ef9945f6-a311-412b-aeda-e1bc8457630d',
#   'index': 1547,
#   'location': [119.0, 79.0],
#   'minute': 40,
#   'pass': {'angle': -1.6680496,
#            'body_part': {'id': 38, 'name': 'Left Foot'},
#            'cross': True,
#            'end_location': [115.0, 38.0],
#            'height': {'id': 3, 'name': 'High Pass'},
#            'length': 41.19466,
#            'outcome': {'id': 9, 'name': 'Incomplete'},
#            'switch': True,
#            'type': {'id': 61, 'name': 'Corner'}},
#   'period': 1,
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'player': {'id': 5503, 'name': 'Lionel Andrés Messi Cuccittini'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'possession': 56,
#   'possession_team': {'id': 779, 'name': 'Argentina'},
#   'related_events': ['c496fef2-b05b-4003-9c38-02a2660f3601'],
#   'second': 22,
#   'team': {'id': 779, 'name': 'Argentina'},
#   'timestamp': '00:40:22.673',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-309-0703c00793a3> in <module>
# ----> 1 pprint(data)
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in pprint(object, stream, indent, width, depth, compact)
#      51         stream=stream, indent=indent, width=width, depth=depth,
#      52         compact=compact)
# ---> 53     printer.pprint(object)
#      54
#      55 def pformat(object, indent=1, width=80, depth=None, *, compact=False):
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in pprint(self, object)
#     137
#     138     def pprint(self, object):
# --> 139         self._format(object, self._stream, 0, 0, {}, 0)
#     140         self._stream.write("\n")
#     141
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     208         stream.write('[')
#     209         self._format_items(object, stream, indent, allowance + 1,
# --> 210                            context, level)
#     211         stream.write(']')
#     212
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     387             self._format(ent, stream, indent,
#     388                          allowance if last else 1,
# --> 389                          context, level)
#     390
#     391     def _repr(self, object, context, level):
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     185         length = len(object)
#     186         if length:
# --> 187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
#     189                                     context, level)
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in _safe_tuple(t)
#      94 def _safe_tuple(t):
#      95     "Helper function for comparing 2-tuples"
# ---> 96     return _safe_key(t[0]), _safe_key(t[1])
#      97
#      98 class PrettyPrinter:
#
# ~/opt/anaconda3/lib/python3.7/pprint.py in __init__(self, obj)
#      83
#      84     def __init__(self, obj):
# ---> 85         self.obj = obj
#      86
#      87     def __lt__(self, other):
#
# KeyboardInterrupt:

# %%
minute = []
team = []
player = []
ball_type = []
location = []
xG = []
outcome = []
col_names = ['Minute','Team','Player','Type','Location','xG','Outcome']
for x in range(len(data)):
    if data[x]['type']['name'] == 'Shot':
        minute.append(data[x]['minute'])
        team.append(data[x]['possession_team']['name'])
        player.append(data[x]['player']['name'])
        ball_type.append(data[x]['type']['name'])
        location.append(data[x]['location'])
        xG.append(data[x]['shot']['statsbomb_xg'])
        outcome.append(data[x]['shot']['outcome']['name'])

# %%
'''
Here we create the data frame with pandas. The data we read in will come in reverse in terms of the columns and rows so
we want to transpose it to flip columns and rows.
'''

df = pd.DataFrame(data=[minute,team,player,ball_type,location,xG,outcome],index=col_names)
df = df.T
df.head()
# Out:
#   Minute       Team                        Player  Type       Location  \
# 0      0    Iceland          Gylfi Þór Sigurðsson  Shot   [96.0, 53.0]
# 1      4  Argentina       Nicolás Hernán Otamendi  Shot  [111.0, 43.0]
# 2      7  Argentina  Nicolás Alejandro Tagliafico  Shot  [105.0, 45.0]
# 3      8    Iceland            Alfreð Finnbogason  Shot  [115.0, 57.0]
# 4      8    Iceland      Johann Berg Guðmunds­son  Shot  [100.0, 54.0]
#
#           xG  Outcome
# 0  0.0214323    Off T
# 1   0.148515    Off T
# 2  0.0241709    Off T
# 3  0.0608888    Off T
# 4  0.0436354  Blocked

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,82], color="white")
plt.plot([0,122],[82,82], color="white")
plt.plot([122,122],[82,0], color="white")
plt.plot([122,0],[0,0], color="white")
plt.plot([61,61],[0,82], color="white")

#Left Penalty Area
plt.plot([16.5,16.5],[57,25],color="white")
plt.plot([0,16.5],[57,57],color="white")
plt.plot([16.5,0],[25,25],color="white")

#Right Penalty Area
plt.plot([122,105.5],[57,57],color="white")
plt.plot([105.5,105.5],[57,25],color="white")
plt.plot([105.5,122],[25,25],color="white")

#Left 6-yard Box
plt.plot([0,5.5],[50,50],color="white")
plt.plot([5.5,5.5],[50,32],color="white")
plt.plot([5.5,0.5],[32,32],color="white")

#Right 6-yard Box
plt.plot([122,116.5],[50,50],color="white")
plt.plot([116.5,116.5],[50,32],color="white")
plt.plot([122,116.5],[32,32],color="white")

#Prepare Circles
centreCircle = plt.Circle((61,41),9.15,color="white",fill=False)
centreSpot = plt.Circle((61,41),0.8,color="white")
leftPenSpot = plt.Circle((11,41),0.8,color="white")
rightPenSpot = plt.Circle((111,41),0.8,color="white")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Tidy Axes
plt.axis('off')
plt.style.use('dark_background')
#plt.scatter(cx,cy,color='blue',label='Argentina')
#plt.scatter(mx,my,color='red',label='Iceland')

a_label = 'Argentina'
b_label = 'Iceland'
for x in range(len(df['Location'])):
    if df['Team'][x] == 'Argentina':
        plt.scatter(df['Location'][x][0],df['Location'][x][1],color='blue',label=a_label)
        a_label = "_nolegend_"
    if df['Team'][x] == 'Iceland':
        plt.scatter(df['Location'][x][0],df['Location'][x][1],color='red',label=b_label)
        b_label = "_nolegend_"
        
plt.legend(loc='lower right',facecolor='black',framealpha=1)
