# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plfrom 
from mplsoccer.pitch import Pitch
import seaborn as sns

# %%
df = pd.read_csv('bcnvalaves.csv')

# %%
riqui = 372827
barca = 65
r_data = df[df["playerId"]==riqui]
r_data
# Out:
#               id  eventId  minute  second  teamId     x      y  \
# 7     2200971995        8       0    14.0      65  39.3   61.2
# 11    2200972039       12       0    28.0      65  51.9   73.3
# 26    2200972135       23       0    54.0      65  40.7   68.4
# 39    2200972295       38       1    44.0      65  68.7   60.0
# 44    2200972317       41       1    54.0      65  72.2   70.2
# ...          ...      ...     ...     ...     ...   ...    ...
# 1546  2201014573     1031      89    59.0      65  56.0  100.0
# 1556  2201014715     1040      90    25.0      65  39.3   91.7
# 1558  2201014725     1042      90    28.0      65  41.8   91.5
# 1560  2201014749     1044      90    31.0      65  39.4   72.9
# 1575  2201014999     1053      91    32.0      65  66.3   70.0
#
#       expandedMinute  period/value period/displayName  ...  \
# 7                  0             1          FirstHalf  ...
# 11                 0             1          FirstHalf  ...
# 26                 0             1          FirstHalf  ...
# 39                 1             1          FirstHalf  ...
# 44                 1             1          FirstHalf  ...
# ...              ...           ...                ...  ...
# 1546              91             2         SecondHalf  ...
# 1556              92             2         SecondHalf  ...
# 1558              92             2         SecondHalf  ...
# 1560              92             2         SecondHalf  ...
# 1575              93             2         SecondHalf  ...
#
#       qualifiers/13/type/displayName blockedX  blockedY  \
# 7                                NaN      NaN       NaN
# 11                               NaN      NaN       NaN
# 26                               NaN      NaN       NaN
# 39                               NaN      NaN       NaN
# 44                               NaN      NaN       NaN
# ...                              ...      ...       ...
# 1546                             NaN      NaN       NaN
# 1556                             NaN      NaN       NaN
# 1558                             NaN      NaN       NaN
# 1560                             NaN      NaN       NaN
# 1575                             NaN      NaN       NaN
#
#      satisfiedEventsTypes/14  qualifiers/13/value  qualifiers/14/type/value  \
# 7                        NaN                  NaN                       NaN
# 11                       NaN                  NaN                       NaN
# 26                       NaN                  NaN                       NaN
# 39                       NaN                  NaN                       NaN
# 44                       NaN                  NaN                       NaN
# ...                      ...                  ...                       ...
# 1546                     NaN                  NaN                       NaN
# 1556                     NaN                  NaN                       NaN
# 1558                     NaN                  NaN                       NaN
# 1560                     NaN                  NaN                       NaN
# 1575                     NaN                  NaN                       NaN
#
#       qualifiers/14/type/displayName qualifiers/14/value  isGoal  \
# 7                                NaN                 NaN     NaN
# 11                               NaN                 NaN     NaN
# 26                               NaN                 NaN     NaN
# 39                               NaN                 NaN     NaN
# 44                               NaN                 NaN     NaN
# ...                              ...                 ...     ...
# 1546                             NaN                 NaN     NaN
# 1556                             NaN                 NaN     NaN
# 1558                             NaN                 NaN     NaN
# 1560                             NaN                 NaN     NaN
# 1575                             NaN                 NaN     NaN
#
#      satisfiedEventsTypes/15
# 7                        NaN
# 11                       NaN
# 26                       NaN
# 39                       NaN
# 44                       NaN
# ...                      ...
# 1546                     NaN
# 1556                     NaN
# 1558                     NaN
# 1560                     NaN
# 1575                     NaN
#
# [94 rows x 86 columns]

# %%
xstart = []
ystart = []
xend = []
yend = []
names = ['x','y']

passes = r_data.loc[r_data['type/displayName'] == 'Pass'] # select rows based on condition
xstart = passes['x'].values #df -> np.array
ystart = passes['y'].values
    
df = pd.DataFrame(data=[xstart,ystart],index=names)
df = df.T

# %%
df
# Out:
#        x      y
# 0   39.3   61.2
# 1   51.9   73.3
# 2   40.7   68.4
# 3   68.7   60.0
# 4   64.0   85.1
# ..   ...    ...
# 65  56.0  100.0
# 66  39.3   91.7
# 67  41.8   91.5
# 68  39.4   72.9
# 69  66.3   70.0
#
# [70 rows x 2 columns]

# %%
def draw_field():
    #create basic lines
    plt.plot([0,0],[0,100],color='white')
    plt.plot([0,100],[0,0],color='white')
    plt.plot([100,0],[100,100],color='white')
    plt.plot([100,100],[0,100],color='white')
    plt.plot([50,50],[0,100],color='white')
    #right side box
    #inner
    plt.plot([94,94],[56,44],color='white')
    plt.plot([94,100],[56,56],color='white')
    plt.plot([94,100],[44,44],color='white')
    plt.scatter(88,50,color='white',s=10)

    #outer
    plt.plot([82,82],[72,28],color='white')
    plt.plot([82,100],[72,72],color='white')
    plt.plot([82,100],[28,28],color='white')

    #left side box
    #inner
    plt.plot([0,6],[56,56],color='white')
    plt.plot([0,6],[44,44],color='white')
    plt.plot([6,6],[56,44],color='white')
    plt.scatter(12,50,color='white',s=10)

    #Outer
    plt.plot([18,18],[72,28],color='white')
    plt.plot([0,18],[72,72],color='white')
    plt.plot([0,18],[28,28],color='white')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)

kde = sns.kdeplot(xstart,
            ystart,
            shade=True,
            color='red',
            shade_lowest=False
            )

draw_field()
plt.scatter(df['x'], df['y'], color='blue') #you can pass arrays and dataframes here
    
plt.title('Riqui Puig Passing Heatmap vs Alaves')
plt.axis('off')
plt.ylim(0, 100) # need this, otherwise plot will go outside
plt.xlim(0, 100)

#plt.savefig('riqui2.png', dpi=300)
# Out:
# (0, 100)
